# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
import random
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn.functional as F

# Check for CUDA
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Define improved transformations - less aggressive augmentation
transform_train = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((48, 48)),
    transforms.RandomResizedCrop(48, scale=(0.85, 1.0)),  # Less scaling
    transforms.RandomHorizontalFlip(p=0.2),
    transforms.RandomRotation(5),  # Reduced rotation
    transforms.RandomAffine(0, translate=(0.1, 0.1), scale=(0.9, 1.1)),  # Less translation/scaling
    transforms.ColorJitter(brightness=0.1, contrast=0.1),  # Reduced color jitter
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

transform_val = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((48, 48)),  # No random crop for validation
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])
# Load dataset
train_data = datasets.ImageFolder("D:/projects/machine learning/Expression-recognition/jonathanheix dataset/images/train", transform=transform_train)
loaded_train = DataLoader(train_data, batch_size=64, shuffle=True, num_workers=4, pin_memory=True)

validation_data = datasets.ImageFolder("D:/projects/machine learning/Expression-recognition/jonathanheix dataset/images/validation", transform=transform_val)
loaded_validation = DataLoader(validation_data, batch_size=64, shuffle=False, num_workers=4, pin_memory=True)

# %%
class EmotionCNN(nn.Module):
    def __init__(self):
        super(EmotionCNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1, bias=True),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 32, kernel_size=3, padding=1, bias=True),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1, bias=True),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, padding=1, bias=True),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1, bias=True),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 128, kernel_size=3, padding=1, bias=True),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Dropout(0.1)  # Dropout after deeper conv blocks
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, padding=1, bias=True),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1, bias=True),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Dropout(0.2)  # Slightly higher dropout in deeper layers
        )
        self.conv5 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, padding=1, bias=True),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, padding=1, bias=True),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Dropout(0.3)  # Stronger dropout to combat overfitting
        )

        # Fully connected layers
        self.fc = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Dropout(0,3),  # Dropout before the final output
            nn.Linear(128, 7)
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = self.fc(x)
        return x

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        p_t = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1 - p_t) ** self.gamma * ce_loss
        return focal_loss.mean()

# %%
# Initialize model, loss, and optimizer
model = EmotionCNN().to(device)
criterion = nn.CrossEntropyLoss(label_smoothing=0.03)  # Apply label smoothing
# criterion = FocalLoss(alpha=0.25, gamma=2)

# Optimizer with weight decay
optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=1e-5)

# Scheduler setup
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5, min_lr=1e-6)

# Mixed precision scaler
scaler = torch.amp.GradScaler("cuda")

train_losses = []
val_losses = []

# Evaluation function
def evaluate_model(model, dataloader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = 100 * correct / total
    return accuracy

# Validation loss calculation
def compute_validation_loss():
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for images, labels in loaded_validation:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
    return val_loss / len(loaded_validation)

# Training function
def train_part(model, optimizer, epochs=10):
    model = model.to(device)
    for epoch in range(epochs):
        print(f"Epoch: {epoch + 1}")
        running_loss = 0.0
        correct = 0
        total = 0
        model.train()

        for images, labels in loaded_train:
            images, labels = images.to(device), labels.to(device, dtype=torch.long)
            optimizer.zero_grad()

            # Mixed precision training
            with torch.amp.autocast("cuda"):
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            

        # Calculate accuracy
        accuracy = 100 * correct / total
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {running_loss/len(loaded_train):.4f}, Train Accuracy: {accuracy:.2f}%")
        print(f"Current learning rate: {scheduler.optimizer.param_groups[0]['lr']:.6f}")

        # Compute validation loss and update scheduler
        val_loss = compute_validation_loss()
        scheduler.step(val_loss)
        train_losses.append(running_loss / len(loaded_train))
        val_losses.append(val_loss)
        val_accuracy = evaluate_model(model, loaded_validation)
        print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%")

    # Plot training and validation losses
    plt.plot(range(1, epochs + 1), train_losses, label="Training Loss", color='blue', linewidth=1, marker='o')
    plt.plot(range(1, epochs + 1), val_losses, label="Validation Loss", color='orange', linewidth=1, marker='o')
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Training and Validation Loss Over Epochs")
    plt.show()


print("Starting training...")
train_part(model, optimizer, epochs=100)
print("Training complete!")

# Final validation accuracy
val_accuracy = evaluate_model(model, loaded_validation)
print(f'Final Validation Accuracy: {val_accuracy:.2f}%')
# Out:
# Starting training...
# Epoch: 1
# Epoch 1/100, Train Loss: 1.6157, Train Accuracy: 36.30%
# Current learning rate: 0.000500
# Validation Loss: 1.3434, Validation Accuracy: 49.99%
# Epoch: 2
# Epoch 2/100, Train Loss: 1.3783, Train Accuracy: 48.44%
# Current learning rate: 0.000500
# Validation Loss: 1.3855, Validation Accuracy: 48.95%
# Epoch: 3
# Epoch 3/100, Train Loss: 1.2868, Train Accuracy: 53.17%
# Current learning rate: 0.000500
# Validation Loss: 1.2117, Validation Accuracy: 56.11%
# Epoch: 4
# Epoch 4/100, Train Loss: 1.2376, Train Accuracy: 54.90%
# Current learning rate: 0.000500
# Validation Loss: 1.1581, Validation Accuracy: 57.76%
# Epoch: 5
# Epoch 5/100, Train Loss: 1.1940, Train Accuracy: 56.90%
# Current learning rate: 0.000500
# Validation Loss: 1.1382, Validation Accuracy: 58.99%
# Epoch: 6
# Epoch 6/100, Train Loss: 1.1666, Train Accuracy: 58.46%
# Current learning rate: 0.000500
# Validation Loss: 1.1948, Validation Accuracy: 57.78%
# Epoch: 7
# Epoch 7/100, Train Loss: 1.1430, Train Accuracy: 59.29%
# Current learning rate: 0.000500
# Validation Loss: 1.1196, Validation Accuracy: 60.27%
# Epoch: 8
# Epoch 8/100, Train Loss: 1.1281, Train Accuracy: 59.86%
# Current learning rate: 0.000500
# Validation Loss: 1.1168, Validation Accuracy: 60.76%
# Epoch: 9
# Epoch 9/100, Train Loss: 1.1067, Train Accuracy: 60.98%
# Current learning rate: 0.000500
# Validation Loss: 1.0884, Validation Accuracy: 61.70%
# Epoch: 10
# Epoch 10/100, Train Loss: 1.0940, Train Accuracy: 61.40%
# Current learning rate: 0.000500
# Validation Loss: 1.0646, Validation Accuracy: 62.89%
# Epoch: 11
# Epoch 11/100, Train Loss: 1.0710, Train Accuracy: 62.32%
# Current learning rate: 0.000500
# Validation Loss: 1.0334, Validation Accuracy: 64.01%
# Epoch: 12
# Epoch 12/100, Train Loss: 1.0567, Train Accuracy: 63.21%
# Current learning rate: 0.000500
# Validation Loss: 1.0793, Validation Accuracy: 61.99%
# Epoch: 13
# Epoch 13/100, Train Loss: 1.0440, Train Accuracy: 63.47%
# Current learning rate: 0.000500
# Validation Loss: 1.1026, Validation Accuracy: 61.38%
# Epoch: 14
# Epoch 14/100, Train Loss: 1.0310, Train Accuracy: 64.10%
# Current learning rate: 0.000500
# Validation Loss: 1.0372, Validation Accuracy: 64.15%
# Epoch: 15
# Epoch 15/100, Train Loss: 1.0231, Train Accuracy: 64.57%
# Current learning rate: 0.000500
# Validation Loss: 1.0127, Validation Accuracy: 65.24%
# Epoch: 16
# Epoch 16/100, Train Loss: 1.0127, Train Accuracy: 65.02%
# Current learning rate: 0.000500
# Validation Loss: 1.0105, Validation Accuracy: 65.57%
# Epoch: 17
# Epoch 17/100, Train Loss: 0.9984, Train Accuracy: 65.59%
# Current learning rate: 0.000500
# Validation Loss: 1.0403, Validation Accuracy: 64.08%
# Epoch: 18
# Epoch 18/100, Train Loss: 0.9932, Train Accuracy: 65.63%
# Current learning rate: 0.000500
# Validation Loss: 1.0635, Validation Accuracy: 63.09%
# Epoch: 19
# Epoch 19/100, Train Loss: 0.9751, Train Accuracy: 66.63%
# Current learning rate: 0.000500
# Validation Loss: 1.0226, Validation Accuracy: 65.07%
# Epoch: 20
# Epoch 20/100, Train Loss: 0.9714, Train Accuracy: 66.89%
# Current learning rate: 0.000500
# Validation Loss: 1.0177, Validation Accuracy: 65.89%
# Epoch: 21
# Epoch 21/100, Train Loss: 0.9539, Train Accuracy: 67.71%
# Current learning rate: 0.000500
# Validation Loss: 1.0065, Validation Accuracy: 66.11%
# Epoch: 22
# Epoch 22/100, Train Loss: 0.9514, Train Accuracy: 67.70%
# Current learning rate: 0.000500
# Validation Loss: 1.0396, Validation Accuracy: 65.27%
# Epoch: 23
# Epoch 23/100, Train Loss: 0.9370, Train Accuracy: 68.61%
# Current learning rate: 0.000500
# Validation Loss: 1.0048, Validation Accuracy: 66.93%
# Epoch: 24
# Epoch 24/100, Train Loss: 0.9344, Train Accuracy: 68.43%
# Current learning rate: 0.000500
# Validation Loss: 1.0037, Validation Accuracy: 65.88%
# Epoch: 25
# Epoch 25/100, Train Loss: 0.9206, Train Accuracy: 68.94%
# Current learning rate: 0.000500
# Validation Loss: 1.0190, Validation Accuracy: 65.23%
# Epoch: 26
# Epoch 26/100, Train Loss: 0.9144, Train Accuracy: 69.44%
# Current learning rate: 0.000500
# Validation Loss: 0.9975, Validation Accuracy: 66.53%
# Epoch: 27
# Epoch 27/100, Train Loss: 0.9122, Train Accuracy: 69.63%
# Current learning rate: 0.000500
# Validation Loss: 1.0189, Validation Accuracy: 65.55%
# Epoch: 28
# Epoch 28/100, Train Loss: 0.8966, Train Accuracy: 70.28%
# Current learning rate: 0.000500
# Validation Loss: 1.0091, Validation Accuracy: 65.95%
# Epoch: 29
# Epoch 29/100, Train Loss: 0.8884, Train Accuracy: 70.51%
# Current learning rate: 0.000500
# Validation Loss: 1.0091, Validation Accuracy: 66.40%
# Epoch: 30
# Epoch 30/100, Train Loss: 0.8858, Train Accuracy: 70.79%
# Current learning rate: 0.000500
# Validation Loss: 0.9774, Validation Accuracy: 67.44%
# Epoch: 31
# Epoch 31/100, Train Loss: 0.8744, Train Accuracy: 71.11%
# Current learning rate: 0.000500
# Validation Loss: 0.9832, Validation Accuracy: 67.72%
# Epoch: 32
# Epoch 32/100, Train Loss: 0.8674, Train Accuracy: 71.42%
# Current learning rate: 0.000500
# Validation Loss: 1.0016, Validation Accuracy: 66.77%
# Epoch: 33
# Epoch 33/100, Train Loss: 0.8629, Train Accuracy: 71.62%
# Current learning rate: 0.000500
# Validation Loss: 0.9611, Validation Accuracy: 67.92%
# Epoch: 34
# Epoch 34/100, Train Loss: 0.8471, Train Accuracy: 72.48%
# Current learning rate: 0.000500
# Validation Loss: 0.9934, Validation Accuracy: 67.01%
# Epoch: 35
# Epoch 35/100, Train Loss: 0.8388, Train Accuracy: 72.87%
# Current learning rate: 0.000500
# Validation Loss: 1.0027, Validation Accuracy: 67.78%
# Epoch: 36
# Epoch 36/100, Train Loss: 0.8314, Train Accuracy: 73.01%
# Current learning rate: 0.000500
# Validation Loss: 0.9887, Validation Accuracy: 67.51%
# Epoch: 37
# Epoch 37/100, Train Loss: 0.8270, Train Accuracy: 73.13%
# Current learning rate: 0.000500
# Validation Loss: 1.0006, Validation Accuracy: 67.24%
# Epoch: 38
# Epoch 38/100, Train Loss: 0.8181, Train Accuracy: 73.53%
# Current learning rate: 0.000500
# Validation Loss: 1.0070, Validation Accuracy: 67.76%
# Epoch: 39
# Epoch 39/100, Train Loss: 0.8128, Train Accuracy: 73.80%
# Current learning rate: 0.000500
# Validation Loss: 0.9975, Validation Accuracy: 66.95%
# Epoch: 40
# Epoch 40/100, Train Loss: 0.7696, Train Accuracy: 75.63%
# Current learning rate: 0.000250
# Validation Loss: 0.9829, Validation Accuracy: 68.68%
# Epoch: 41
# Epoch 41/100, Train Loss: 0.7537, Train Accuracy: 76.33%
# Current learning rate: 0.000250
# Validation Loss: 0.9662, Validation Accuracy: 68.99%
# Epoch: 42
# Epoch 42/100, Train Loss: 0.7473, Train Accuracy: 76.54%
# Current learning rate: 0.000250
# Validation Loss: 0.9782, Validation Accuracy: 68.75%
# Epoch: 43
# Epoch 43/100, Train Loss: 0.7345, Train Accuracy: 77.02%
# Current learning rate: 0.000250
# Validation Loss: 0.9674, Validation Accuracy: 69.78%
# Epoch: 44
# Epoch 44/100, Train Loss: 0.7287, Train Accuracy: 77.23%
# Current learning rate: 0.000250
# Validation Loss: 0.9870, Validation Accuracy: 68.81%
# Epoch: 45
# Epoch 45/100, Train Loss: 0.7212, Train Accuracy: 77.82%
# Current learning rate: 0.000250
# Validation Loss: 0.9698, Validation Accuracy: 68.86%
# Epoch: 46
# Epoch 46/100, Train Loss: 0.6981, Train Accuracy: 78.71%
# Current learning rate: 0.000125
# Validation Loss: 0.9729, Validation Accuracy: 69.45%
# Epoch: 47
# Epoch 47/100, Train Loss: 0.6928, Train Accuracy: 78.88%
# Current learning rate: 0.000125
# Validation Loss: 0.9668, Validation Accuracy: 69.94%
# Epoch: 48
# Epoch 48/100, Train Loss: 0.6897, Train Accuracy: 78.83%
# Current learning rate: 0.000125
# Validation Loss: 0.9762, Validation Accuracy: 69.80%
# Epoch: 49
# Epoch 49/100, Train Loss: 0.6837, Train Accuracy: 79.24%
# Current learning rate: 0.000125
# Validation Loss: 0.9951, Validation Accuracy: 69.62%
# Epoch: 50
# Epoch 50/100, Train Loss: 0.6803, Train Accuracy: 79.57%
# Current learning rate: 0.000125
# Validation Loss: 0.9830, Validation Accuracy: 69.81%
# Epoch: 51
# Epoch 51/100, Train Loss: 0.6777, Train Accuracy: 79.40%
# Current learning rate: 0.000125
# Validation Loss: 0.9767, Validation Accuracy: 69.78%
# Epoch: 52
# Epoch 52/100, Train Loss: 0.6621, Train Accuracy: 80.21%
# Current learning rate: 0.000063
# Validation Loss: 0.9826, Validation Accuracy: 70.01%
# Epoch: 53
# Epoch 53/100, Train Loss: 0.6530, Train Accuracy: 80.45%
# Current learning rate: 0.000063
# Validation Loss: 0.9859, Validation Accuracy: 69.80%
# Epoch: 54
# Epoch 54/100, Train Loss: 0.6562, Train Accuracy: 80.72%
# Current learning rate: 0.000063
# Validation Loss: 0.9851, Validation Accuracy: 70.03%
# Epoch: 55
# Epoch 55/100, Train Loss: 0.6489, Train Accuracy: 81.23%
# Current learning rate: 0.000063
# Validation Loss: 0.9835, Validation Accuracy: 69.84%
# Epoch: 56
# Epoch 56/100, Train Loss: 0.6444, Train Accuracy: 80.88%
# Current learning rate: 0.000063
# Validation Loss: 0.9855, Validation Accuracy: 69.81%
# Epoch: 57
# Epoch 57/100, Train Loss: 0.6404, Train Accuracy: 81.02%
# Current learning rate: 0.000063
# Validation Loss: 0.9837, Validation Accuracy: 70.31%
# Epoch: 58
# Epoch 58/100, Train Loss: 0.6413, Train Accuracy: 81.38%
# Current learning rate: 0.000031
# Validation Loss: 0.9820, Validation Accuracy: 69.90%
# Epoch: 59
# Epoch 59/100, Train Loss: 0.6352, Train Accuracy: 81.35%
# Current learning rate: 0.000031
# Validation Loss: 0.9857, Validation Accuracy: 69.86%
# Epoch: 60
# Epoch 60/100, Train Loss: 0.6360, Train Accuracy: 81.30%
# Current learning rate: 0.000031
# Validation Loss: 0.9816, Validation Accuracy: 70.01%
# Epoch: 61
# Epoch 61/100, Train Loss: 0.6311, Train Accuracy: 81.74%
# Current learning rate: 0.000031
# Validation Loss: 0.9928, Validation Accuracy: 69.70%
# Epoch: 62
# Epoch 62/100, Train Loss: 0.6324, Train Accuracy: 81.40%
# Current learning rate: 0.000031
# Validation Loss: 0.9886, Validation Accuracy: 69.80%
# Epoch: 63
# Epoch 63/100, Train Loss: 0.6323, Train Accuracy: 81.28%
# Current learning rate: 0.000031
# Validation Loss: 0.9872, Validation Accuracy: 70.11%
# Epoch: 64
# Epoch 64/100, Train Loss: 0.6301, Train Accuracy: 81.67%
# Current learning rate: 0.000016
# Validation Loss: 0.9835, Validation Accuracy: 70.10%
# Epoch: 65
# Epoch 65/100, Train Loss: 0.6294, Train Accuracy: 81.70%
# Current learning rate: 0.000016
# Validation Loss: 0.9849, Validation Accuracy: 70.31%
# Epoch: 66
# Epoch 66/100, Train Loss: 0.6246, Train Accuracy: 81.97%
# Current learning rate: 0.000016
# Validation Loss: 0.9940, Validation Accuracy: 69.94%
# Epoch: 67
# Epoch 67/100, Train Loss: 0.6210, Train Accuracy: 82.07%
# Current learning rate: 0.000016
# Validation Loss: 0.9889, Validation Accuracy: 70.07%
# Epoch: 68
# Epoch 68/100, Train Loss: 0.6234, Train Accuracy: 81.92%
# Current learning rate: 0.000016
# Validation Loss: 0.9921, Validation Accuracy: 70.21%
# Epoch: 69
# Epoch 69/100, Train Loss: 0.6226, Train Accuracy: 81.90%
# Current learning rate: 0.000016
# Validation Loss: 0.9895, Validation Accuracy: 70.18%
# Epoch: 70
# Epoch 70/100, Train Loss: 0.6185, Train Accuracy: 82.03%
# Current learning rate: 0.000008
# Validation Loss: 0.9956, Validation Accuracy: 70.11%
# Epoch: 71
# Epoch 71/100, Train Loss: 0.6162, Train Accuracy: 82.09%
# Current learning rate: 0.000008
# Validation Loss: 0.9906, Validation Accuracy: 70.32%
# Epoch: 72
# Epoch 72/100, Train Loss: 0.6200, Train Accuracy: 82.04%
# Current learning rate: 0.000008
# Validation Loss: 0.9921, Validation Accuracy: 70.28%
# Epoch: 73
# Epoch 73/100, Train Loss: 0.6214, Train Accuracy: 82.12%
# Current learning rate: 0.000008
# Validation Loss: 0.9914, Validation Accuracy: 70.25%
# Epoch: 74
# Epoch 74/100, Train Loss: 0.6213, Train Accuracy: 81.95%
# Current learning rate: 0.000008
# Validation Loss: 0.9896, Validation Accuracy: 70.24%
# Epoch: 75
# Epoch 75/100, Train Loss: 0.6178, Train Accuracy: 82.25%
# Current learning rate: 0.000008
# Validation Loss: 0.9907, Validation Accuracy: 69.98%
# Epoch: 76
# Epoch 76/100, Train Loss: 0.6258, Train Accuracy: 81.86%
# Current learning rate: 0.000004
# Validation Loss: 0.9935, Validation Accuracy: 70.07%
# Epoch: 77
# Epoch 77/100, Train Loss: 0.6230, Train Accuracy: 82.11%
# Current learning rate: 0.000004
# Validation Loss: 0.9869, Validation Accuracy: 70.21%
# Epoch: 78
# Epoch 78/100, Train Loss: 0.6148, Train Accuracy: 82.13%
# Current learning rate: 0.000004
# Validation Loss: 0.9901, Validation Accuracy: 70.27%
# Epoch: 79
# Epoch 79/100, Train Loss: 0.6163, Train Accuracy: 82.28%
# Current learning rate: 0.000004
# Validation Loss: 0.9926, Validation Accuracy: 70.42%
# Epoch: 80
# Epoch 80/100, Train Loss: 0.6151, Train Accuracy: 82.44%
# Current learning rate: 0.000004
# Validation Loss: 0.9916, Validation Accuracy: 70.32%
# Epoch: 81
# Epoch 81/100, Train Loss: 0.6165, Train Accuracy: 82.26%
# Current learning rate: 0.000004
# Validation Loss: 0.9900, Validation Accuracy: 70.38%
# Epoch: 82
# Epoch 82/100, Train Loss: 0.6213, Train Accuracy: 82.00%
# Current learning rate: 0.000002
# Validation Loss: 0.9887, Validation Accuracy: 70.42%
# Epoch: 83
# Epoch 83/100, Train Loss: 0.6163, Train Accuracy: 82.27%
# Current learning rate: 0.000002
# Validation Loss: 0.9921, Validation Accuracy: 70.29%
# Epoch: 84
# Epoch 84/100, Train Loss: 0.6118, Train Accuracy: 82.33%
# Current learning rate: 0.000002
# Validation Loss: 0.9880, Validation Accuracy: 70.41%
# Epoch: 85
# Epoch 85/100, Train Loss: 0.6103, Train Accuracy: 82.53%
# Current learning rate: 0.000002
# Validation Loss: 0.9940, Validation Accuracy: 70.32%
# Epoch: 86
# Epoch 86/100, Train Loss: 0.6124, Train Accuracy: 82.48%
# Current learning rate: 0.000002
# Validation Loss: 0.9915, Validation Accuracy: 70.22%
# Epoch: 87
# Epoch 87/100, Train Loss: 0.6136, Train Accuracy: 82.42%
# Current learning rate: 0.000002
# Validation Loss: 0.9933, Validation Accuracy: 70.38%
# Epoch: 88
# Epoch 88/100, Train Loss: 0.6186, Train Accuracy: 82.39%
# Current learning rate: 0.000001
# Validation Loss: 0.9903, Validation Accuracy: 70.31%
# Epoch: 89
# Epoch 89/100, Train Loss: 0.6122, Train Accuracy: 82.37%
# Current learning rate: 0.000001
# Validation Loss: 0.9909, Validation Accuracy: 70.51%
# Epoch: 90
# Epoch 90/100, Train Loss: 0.6198, Train Accuracy: 81.96%
# Current learning rate: 0.000001
# Validation Loss: 0.9942, Validation Accuracy: 70.28%
# Epoch: 91
# Epoch 91/100, Train Loss: 0.6193, Train Accuracy: 82.05%
# Current learning rate: 0.000001
# Validation Loss: 0.9939, Validation Accuracy: 70.35%
# Epoch: 92
# Epoch 92/100, Train Loss: 0.6162, Train Accuracy: 82.27%
# Current learning rate: 0.000001
# Validation Loss: 0.9934, Validation Accuracy: 70.41%
# Epoch: 93
# Epoch 93/100, Train Loss: 0.6181, Train Accuracy: 82.11%
# Current learning rate: 0.000001
# Validation Loss: 0.9928, Validation Accuracy: 70.29%
# Epoch: 94
# Epoch 94/100, Train Loss: 0.6171, Train Accuracy: 82.39%
# Current learning rate: 0.000001
# Validation Loss: 0.9900, Validation Accuracy: 70.35%
# Epoch: 95
# Epoch 95/100, Train Loss: 0.6095, Train Accuracy: 82.58%
# Current learning rate: 0.000001
# Validation Loss: 0.9902, Validation Accuracy: 70.46%
# Epoch: 96
# Epoch 96/100, Train Loss: 0.6145, Train Accuracy: 82.14%
# Current learning rate: 0.000001
# Validation Loss: 0.9921, Validation Accuracy: 70.21%
# Epoch: 97
# Epoch 97/100, Train Loss: 0.6108, Train Accuracy: 82.50%
# Current learning rate: 0.000001
# Validation Loss: 0.9944, Validation Accuracy: 70.32%
# Epoch: 98
# Epoch 98/100, Train Loss: 0.6133, Train Accuracy: 82.06%
# Current learning rate: 0.000001
# Validation Loss: 0.9918, Validation Accuracy: 70.21%
# Epoch: 99
# Epoch 99/100, Train Loss: 0.6180, Train Accuracy: 82.07%
# Current learning rate: 0.000001
# Validation Loss: 0.9919, Validation Accuracy: 70.20%
# Epoch: 100
# Epoch 100/100, Train Loss: 0.6154, Train Accuracy: 82.25%
# Current learning rate: 0.000001
# Validation Loss: 0.9949, Validation Accuracy: 70.11%
# Training complete!
# Final Validation Accuracy: 70.11%

# %%
# Visualization setup
dataiter = iter(loaded_train)
images, labels = next(dataiter)
expression = {0: "angry", 1: "disgust", 2: "fear", 3: "happy", 4: "neutral", 5: "sad", 6: "surprise"}

# Display a random image and its label
random_idx = random.randint(0, 63)
print("Target label:", expression[int(labels[random_idx].cpu().numpy())])
plt.imshow(np.transpose(images[random_idx].cpu().numpy(), (1, 2, 0)), cmap='gray')
plt.show()
# Out:
# Target label: sad

# %%
# Evaluate the model and make predictions on 5 random images
model.eval()
dataiter = iter(loaded_validation)
images, labels = next(dataiter)
images, labels = images.to(device), labels.to(device)

outputs = model(images)
_, predicted = torch.max(outputs, 1)

expression = {0: "angry", 1: "disgust", 2: "fear", 3: "happy", 4: "neutral", 5: "sad", 6: "surprise"}

# Display 5 random images with their predicted and true labels
fig, axes = plt.subplots(1, 5, figsize=(15, 5))
for i in range(5):
    random_idx = random.randint(0, len(images) - 1)
    axes[i].imshow(np.transpose(images[random_idx].cpu().numpy(), (1, 2, 0)), cmap='gray')
    axes[i].set_title(f"Predicted: {expression[int(predicted[random_idx].cpu().numpy())]}\nTrue: {expression[int(labels[random_idx].cpu().numpy())]}")
    axes[i].axis('off')
plt.show()
