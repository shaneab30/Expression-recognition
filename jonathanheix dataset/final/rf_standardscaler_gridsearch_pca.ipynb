# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
import os
from PIL import Image
from sklearn.model_selection import GridSearchCV
from pickle import dump, load
from sklearn.model_selection import ParameterGrid
from sklearn.ensemble import RandomForestClassifier

# %%
# def load_images(images_folder, save_file_to=None):
    
#     X_original = []
#     X = []
#     y = []
    
#     for subdir, dirs, files in os.walk(images_folder):
#         for file in files:
#             if file.endswith(('jpg', 'jpeg', 'png')):
#                 img_path = os.path.join(subdir, file)
#                 label = os.path.basename(subdir)
                
#                 image = Image.open(img_path).convert('L')
#                 image = image.resize((64, 64))
#                 X_original.append(np.array(image).flatten())
#                 X.append(np.array(image).flatten())
#                 y.append(label)
                
#     if save_file_to:
#         with open(save_file_to, "wb") as f:
#             dump((X, y), f, protocol=5)
                
#     return np.array(X_original), np.array(X), np.array(y)

# images_folder = '/Users/shaneab/Projects/Machine Learning/Expression recognition/jonathanheix dataset/images'
# dataset_file = "dataset_dump.pkl"

# # Load images and save the dataset for reuse
# X_original, X, y = load_images(images_folder, save_file_to=dataset_file)

# %%
with open("dataset_dump.pkl", "rb") as f:
    X_original,X,y = load(f)
    
X
y
# Out:
# ['happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  ...]

# %%
# Convert lists to NumPy arrays
X = np.array(X)
y = np.array(y)

# %%
# def preprocessing_data(X, y, save_file_to=None):
#     # Normalize pixel values
#     X = X / 255.0  # Normalize to [0, 1]
    
#     # Encode labels
#     label_encoder = LabelEncoder()
#     y_encoded = label_encoder.fit_transform(y)
    
#     # Dimensionality reduction with PCA
#     pca = PCA(n_components=100)
#     X_reduced = pca.fit_transform(X)
    
#     # Standardize the data
#     scaler = StandardScaler()
#     X_scaled = scaler.fit_transform(X_reduced)
    
#     if save_file_to:
#         with open(save_file_to, "wb") as f:
#             dump((X_scaled, y_encoded, label_encoder, pca, scaler), f, protocol=5)
    
#     return X_scaled, y_encoded, label_encoder, pca, scaler

# X_scaled, y_encoded, label_encoder, pca, scaler = preprocessing_data(X, y, save_file_to="labelencoder_standardscaler_pca_normalizers_dump.pkl")

# # with open("svc_standardscaler_gridsearch_normalizers_dump.pkl", "wb") as f:
# #     dump((label_encoder, pca, scaler), f, protocol=5)

# %%
with open("labelencoder_standardscaler_pca_normalizers_dump.pkl", "rb") as f:
    X_scaled, y_encoded, label_encoder, pca, scaler = load(f)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
def train_and_evaluate_random_forest(X_train, y_train, X_test, y_test, label_encoder):
    param_grid = {
        'n_estimators': [50, 100, 150],  # Number of trees
        'max_depth': [10, 20, None],     # Depth of each tree
        'min_samples_split': [2, 5, 10], # Minimum samples for a split
        'min_samples_leaf': [1, 2, 4]    # Minimum samples per leaf
    }

    best_combination = None
    best_accuracy = 0

    all_combinations = list(ParameterGrid(param_grid))
    for combination in all_combinations:
        print(combination)
        rf_model = RandomForestClassifier(**combination, random_state=42)
        rf_model.fit(X_train, y_train)
        
        # Make predictions
        y_pred = rf_model.predict(X_test)
        
        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        print(f"Accuracy: {accuracy:.2f}")
        print("Classification Report:")
        print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
        
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_combination = combination
    
    # Print the best combination
    print("\nBest Combination:", best_combination)
    print(f"Best Accuracy: {best_accuracy:.2f}")
    print("\nTotal combinations:", len(all_combinations))

    # Train the best model on the entire training set
    best_model = RandomForestClassifier(**best_combination, random_state=42)
    best_model.fit(X_train, y_train)

    # Save the best model
    with open("random_forest_model_standardscaler_grisearch_pca_dump.pkl", "wb") as f:
        dump(best_model, f, protocol=5)
    print("Best model saved successfully!")

    return best_model, best_combination

best_model, best_combination = train_and_evaluate_random_forest(X_train, y_train, X_test, y_test, label_encoder)
# Out:
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Accuracy: 0.50
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.94      0.17      0.29      2001
#      disgust       0.83      0.02      0.04       231
#         fear       0.86      0.27      0.41      2068
#        happy       0.38      0.94      0.54      3578
#      neutral       0.60      0.41      0.48      2441
#          sad       0.59      0.39      0.47      2429
#     surprise       0.75      0.56      0.64      1607
#
#     accuracy                           0.50     14355
#    macro avg       0.71      0.39      0.41     14355
# weighted avg       0.65      0.50      0.47     14355
#
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy: 0.50
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.98      0.17      0.29      2001
#      disgust       0.83      0.02      0.04       231
#         fear       0.91      0.26      0.41      2068
#        happy       0.38      0.95      0.54      3578
#      neutral       0.63      0.42      0.50      2441
#          sad       0.62      0.40      0.49      2429
#     surprise       0.76      0.57      0.65      1607
#
#     accuracy                           0.50     14355
#    macro avg       0.73      0.40      0.42     14355
# weighted avg       0.67      0.50      0.48     14355
#
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# Accuracy: 0.50
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.99      0.17      0.29      2001
#      disgust       0.83      0.02      0.04       231
#         fear       0.91      0.27      0.42      2068
#        happy       0.38      0.96      0.54      3578
#      neutral       0.64      0.42      0.51      2441
#          sad       0.63      0.39      0.49      2429
#     surprise       0.76      0.56      0.65      1607
#
#     accuracy                           0.50     14355
#    macro avg       0.74      0.40      0.42     14355
# weighted avg       0.68      0.50      0.48     14355
#
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# Accuracy: 0.49
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.98      0.16      0.28      2001
#      disgust       0.83      0.02      0.04       231
#         fear       0.86      0.25      0.39      2068
#        happy       0.37      0.95      0.54      3578
#      neutral       0.61      0.40      0.48      2441
#          sad       0.61      0.39      0.48      2429
#     surprise       0.75      0.55      0.63      1607
#
#     accuracy                           0.49     14355
#    macro avg       0.72      0.39      0.41     14355
# weighted avg       0.66      0.49      0.46     14355
#
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Accuracy: 0.50
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.97      0.16      0.27      2001
#      disgust       0.83      0.02      0.04       231
#         fear       0.89      0.26      0.40      2068
#        happy       0.37      0.96      0.54      3578
#      neutral       0.62      0.41      0.49      2441
#          sad       0.63      0.39      0.49      2429
#     surprise       0.78      0.55      0.65      1607
#
#     accuracy                           0.50     14355
#    macro avg       0.73      0.39      0.41     14355
# weighted avg       0.67      0.50      0.47     14355
#
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 150}
# Accuracy: 0.50
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.99      0.16      0.27      2001
#      disgust       0.86      0.03      0.05       231
#         fear       0.92      0.25      0.40      2068
#        happy       0.37      0.96      0.54      3578
#      neutral       0.63      0.41      0.50      2441
#          sad       0.63      0.40      0.49      2429
#     surprise       0.78      0.56      0.65      1607
#
#     accuracy                           0.50     14355
#    macro avg       0.74      0.39      0.41     14355
# weighted avg       0.68      0.50      0.47     14355
#
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators':
'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Accuracy: 0.49
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.97      0.15      0.25      2001
#      disgust       0.86      0.03      0.05       231
#         fear       0.86      0.24      0.37      2068
#        happy       0.37      0.95      0.53      3578
#      neutral       0.62      0.40      0.49      2441
#          sad       0.60      0.40      0.48      2429
#     surprise       0.74      0.55      0.63      1607
#
#     accuracy                           0.49     14355
#    macro avg       0.72      0.39      0.40     14355
# weighted avg       0.66      0.49      0.46     14355
#
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 150}
# Accuracy: 0.49
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.99      0.15      0.26      2001
#      disgust       0.86      0.03      0.05       231
#         fear       0.89      0.24      0.38      2068
#        happy       0.37      0.95      0.53      3578
#      neutral       0.62      0.41      0.49      2441
#          sad       0.62      0.39      0.47      2429
#     surprise       0.75      0.55      0.63      1607
#
#     accuracy                           0.49     14355
#    macro avg       0.73      0.39      0.40     14355
# weighted avg       0.67      0.49      0.46     14355
#
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 50}
# Accuracy: 0.48
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.93      0.15      0.25      2001
#      disgust       0.83      0.02      0.04       231
#         fear       0.86      0.23      0.36      2068
#        happy       0.37      0.94      0.53      3578
#      neutral       0.57      0.39      0.46      2441
#          sad       0.57      0.37      0.45      2429
#     surprise       0.73      0.55      0.63      1607
#
#     accuracy                           0.48     14355
#    macro avg       0.70      0.38      0.39     14355
# weighted avg       0.63      0.48      0.45     14355
#
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Accuracy: 0.48
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.96      0.14      0.25      2001
#      disgust       0.83      0.02      0.04       231
#         fear       0.88      0.22      0.36      2068
#        happy       0.37      0.95      0.53      3578
#      neutral       0.62      0.39      0.48      2441
#          sad       0.60      0.37      0.46      2429
#     surprise       0.74      0.54      0.62      1607
#
#     accuracy                           0.48     14355
#    macro avg       0.71      0.38      0.39     14355
# weighted avg       0.65      0.48      0.45     14355
#
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 150}
# Accuracy: 0.48
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.98      0.14      0.24      2001
#      disgust       0.83      0.02      0.04       231
#         fear       0.91      0.23      0.37      2068
#        happy       0.37      0.96      0.53      3578
#      neutral       0.61      0.40      0.48      2441
#          sad       0.61      0.37      0.46      2429
#     surprise       0.75      0.55      0.63      1607
#
#     accuracy                           0.48     14355
#    macro avg       0.72      0.38      0.39     14355
# weighted avg       0.66      0.48      0.45     14355
#
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# Accuracy: 0.48
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.96      0.15      0.26      2001
#      disgust       0.80      0.02      0.03       231
#         fear       0.81      0.23      0.36      2068
#        happy       0.37      0.94      0.53      3578
#      neutral       0.59      0.39      0.47      2441
#          sad       0.55      0.38      0.45      2429
#     surprise       0.74      0.54      0.62      1607
#
#     accuracy                           0.48     14355
#    macro avg       0.69      0.38      0.39     14355
# weighted avg       0.63      0.48      0.45     14355
#
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy: 0.48
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.97      0.14      0.25      2001
#      disgust       0.83      0.02      0.04       231
#         fear       0.85      0.23      0.36      2068
#        happy       0.37      0.95      0.53      3578
#      neutral       0.61      0.39      0.48      2441
#          sad       0.58      0.38      0.46      2429
#     surprise       0.74      0.54      0.63      1607
#
#     accuracy                           0.48     14355
#    macro avg       0.71      0.38      0.39     14355
# weighted avg       0.65      0.48      0.45     14355
#
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 150}
# Accuracy: 0.48
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0
'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# Accuracy: 0.87
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.95      0.80      0.87      2001
#      disgust       0.99      0.52      0.68       231
#         fear       0.93      0.83      0.88      2068
#        happy       0.78      0.95      0.86      3578
#      neutral       0.89      0.88      0.88      2441
#          sad       0.86      0.84      0.85      2429
#     surprise       0.94      0.91      0.92      1607
#
#     accuracy                           0.87     14355
#    macro avg       0.91      0.82      0.85     14355
# weighted avg       0.88      0.87      0.87     14355
#
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# Accuracy: 0.88
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.98      0.81      0.89      2001
#      disgust       0.99      0.56      0.72       231
#         fear       0.95      0.84      0.89      2068
#        happy       0.78      0.96      0.86      3578
#      neutral       0.90      0.88      0.89      2441
#          sad       0.87      0.85      0.86      2429
#     surprise       0.94      0.92      0.93      1607
#
#     accuracy                           0.88     14355
#    macro avg       0.92      0.83      0.86     14355
# weighted avg       0.89      0.88      0.88     14355
#
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 150}
# Accuracy: 0.88
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.99      0.81      0.89      2001
#      disgust       0.99      0.57      0.73       231
#         fear       0.96      0.83      0.89      2068
#        happy       0.77      0.96      0.86      3578
#      neutral       0.90      0.88      0.89      2441
#          sad       0.88      0.85      0.86      2429
#     surprise       0.94      0.93      0.94      1607
#
#     accuracy                           0.88     14355
#    macro avg       0.92      0.83      0.86     14355
# weighted avg       0.89      0.88      0.88     14355
#
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# Accuracy: 0.86
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.95      0.80      0.87      2001
#      disgust       0.99      0.40      0.57       231
#         fear       0.93      0.82      0.88      2068
#        happy       0.78      0.94      0.85      3578
#      neutral       0.87      0.88      0.88      2441
#          sad       0.86      0.84      0.85      2429
#     surprise       0.93      0.90      0.91      1607
#
#     accuracy                           0.86     14355
#    macro avg       0.90      0.80      0.83     14355
# weighted avg       0.87      0.86      0.86     14355
#
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Accuracy: 0.87
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.98      0.81      0.88      2001
#      disgust       0.99      0.44      0.61       231
#         fear       0.95      0.83      0.89      2068
#        happy       0.77      0.96      0.85      3578
#      neutral       0.89      0.88      0.88      2441
#          sad       0.87      0.84      0.85      2429
#     surprise       0.93      0.92      0.93      1607
#
#     accuracy                           0.87     14355
#    macro avg       0.91      0.81      0.84     14355
# weighted avg       0.88      0.87      0.87     14355
#
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 150}
# Accuracy: 0.87
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.98      0.81      0.89      2001
#      disgust       0.99      0.45      0.61       231
#         fear       0.96      0.83      0.89      2068
#        happy       0.76      0.96      0.85      3578
#      neutral       0.89      0.88      0.89      2441
#          sad       0.89      0.84      0.86      2429
#     surprise       0.94      0.92      0.93      1607
#
#     accuracy                           0.87     14355
#    macro avg       0.92      0.81      0.85     14355
# weighted avg       0.89      0.87      0.87     14355
#
#
# Best Combination: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# Best Accuracy: 0.89
#
# Total combinations: 81
# Best model saved successfully!

# %%
def visualize_predictions(best_model, X_test, y_test, label_encoder, X_original):
    y_pred = best_model.predict(X_test)
    random_indices = np.random.randint(0, len(y_test), 5)
    
    for idx in random_indices:
        original_image = X_original[idx].reshape(64, 64)  # Reshape to 48x48
        plt.imshow(original_image, cmap='gray')
        plt.title(f"True: {label_encoder.inverse_transform([y_test[idx]])[0]}, "
                  f"Predicted: {label_encoder.inverse_transform([y_pred[idx]])[0]}")
        plt.axis('off')
        plt.show()

visualize_predictions(best_model, X_test, y_test, label_encoder, X_original)
